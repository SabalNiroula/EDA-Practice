# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = sns.load_dataset('titanic')
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # EDA using univariate analysis
# ​
# - first on categorical data
# ​
# 1. `countplot`
# 2. `piechart`
# ​
# - second on numerical data
# ​
# 1. `boxplot`
# 2. `histogram`
# 3. `distplot`
# ​

# %% [markdown]
# # EDA on Categorical Data

# %%
import seaborn as sns
sns.countplot(x=data['embark_town'] )
# Out:
# <AxesSubplot:xlabel='embark_town', ylabel='count'>

# %%
# print(type(data['Embarked'].tolist()))
data['pclass'].value_counts().plot(kind='pie', autopct="%.2f")
# plt.pie(data['Pclass'].value_counts().tolist(), labels = data['Pclass'].unique().tolist(), autopct='%.2f')#not working
# Out:
# <AxesSubplot:ylabel='pclass'>

# %% [markdown]
# # EDA on Numerical Data

# %%
sns.boxplot(x=data['age'])
# Out:
# <AxesSubplot:xlabel='age'>

# %%
plt.hist(x=data['age'], bins=5)
# Out:
# (array([100., 346., 188.,  69.,  11.]),
#  array([ 0.42 , 16.336, 32.252, 48.168, 64.084, 80.   ]),
#  <BarContainer object of 5 artists>)

# %%
sns.displot(x=data['age'], kde=True, color='red') # the line is kde

# %%
plt.hist(data['age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
sns.kdeplot(x='age', data=data)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
pd.crosstab(data['pclass'], data['sex'])
# Out:
# sex     female  male
# pclass
# 1           94   122
# 2           76   108
# 3          144   347
